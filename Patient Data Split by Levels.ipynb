# %%
import pandas as pd 
import os 
import numpy as np
from openpyxl import load_workbook
import xlsxwriter

# %%
# Read the files 
file = "/Users/doristai/Documents/GitHub/final_project/Resources/cancer_patient_data_sets_with_scores(1).xlsx"

# %%
raw = pd.read_excel(file)
raw.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   35       1              4            5             6
# 1   37       1              7            7             7
# 2   46       1              6            8             7
# 3   35       1              4            5             6
# 4   44       1              6            7             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     5             5                     4              6
# 1                     7             6                     7              7
# 2                     7             7                     6              7
# 3                     5             5                     4              6
# 4                     7             7                     6              7
#
#    Obesity  ...  Weight Loss  Shortness of Breath  Wheezing  \
# 0        7  ...            7                    9         2
# ...

# %%
# Extract Patient Data -- High risk
high_risk = raw[raw['Level'] == 'High']
high_writer = pd.ExcelWriter('High_risk_patient_data.xlsx')
high_risk.to_excel(high_writer, 'High')
high_writer.save()

# %%
high_risk.head(5)
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   35       1              4            5             6
# 1   37       1              7            7             7
# 2   46       1              6            8             7
# 3   35       1              4            5             6
# 4   44       1              6            7             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     5             5                     4              6
# 1                     7             6                     7              7
# 2                     7             7                     6              7
# 3                     5             5                     4              6
# 4                     7             7                     6              7
#
#    Obesity  ...  Weight Loss  Shortness of Breath  Wheezing  \
# 0        7  ...            7                    9         2
# ...

# %%
# Extract Patient Data -- Medium risk
medium_risk = raw[raw['Level'] == 'Medium']
medium_writer = pd.ExcelWriter('Medium_risk_patient_data.xlsx')
medium_risk.to_excel(medium_writer, 'Medium')
medium_writer.save()

# %%
# Extract Patient Data -- Low risk
low_risk = raw[raw['Level'] == 'Low']
low_writer = pd.ExcelWriter('Low_risk_patient_data.xlsx')
low_risk.to_excel(low_writer, 'Low')
low_writer.save()
