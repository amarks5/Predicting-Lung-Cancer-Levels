# %%
import pandas as pd 
import os 
import numpy as np
from openpyxl import load_workbook
import xlsxwriter

# %%
# Read the files 
file = "/Users/doristai/Documents/GitHub/final_project/Resources/cancer_patient_data_sets_with_scores(1).xlsx"

# %%
raw = pd.read_excel(file)
raw.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   35       1              4            5             6
# 1   37       1              7            7             7
# 2   46       1              6            8             7
# 3   35       1              4            5             6
# 4   44       1              6            7             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     5             5                     4              6
# 1                     7             6                     7              7
# 2                     7             7                     6              7
# 3                     5             5                     4              6
# 4                     7             7                     6              7
#
#    Obesity  ...  Weight Loss  Shortness of Breath  Wheezing  \
# 0        7  ...            7                    9         2
# ...

# %%
# High risk profile
high_risk = raw[raw['Level'] == 'High']
high_average = np.mean(high_risk['Score'])
high_first_qrt = np.percentile(high_risk['Score'], 25)
high_second_qrt = np.percentile(high_risk['Score'], 50)
high_third_qrt = np.percentile(high_risk['Score'], 75)
iqr = high_thrid_qrt - high_first_qrt
high_risk_max = max(high_risk['Score'])
print(f'High Risk Patients Stats : \nmax : {high_risk_max}\n25% : {high_first_qrt}\nmean : {high_second_qrt}\n75% : {high_thrid_qrt}\nIQR : {iqr}')
# Out:
# High Risk Patients Stats :
# max : 6.571428571428571
# 25% : 5.285714285714286
# mean : 5.714285714285714
# 75% : 5.904761904761905
# IQR : 0.6190476190476195

# %%
# Medium risk profile
medium_risk = raw[raw['Level'] == 'Medium']
medium_average = np.mean(medium_risk['Score'])
medium_first_qrt = np.percentile(medium_risk['Score'], 25)
medium_second_qrt = np.percentile(medium_risk['Score'], 50)
medium_third_qrt = np.percentile(medium_risk['Score'], 75)
medium_iqr = medium_thrid_qrt - medium_first_qrt
medium_risk_max = max(medium_risk['Score'])
print(f'Medium Risk Patients Stats : \nmax : {medium_risk_max}\n25% : {medium_first_qrt}\nmean : {medium_second_qrt}\n75% : {medium_thrid_qrt}\nIQR : {medium_iqr}')
# Out:
# Medium Risk Patients Stats :
# max : 4.857142857142857
# 25% : 3.3333333333333335
# mean : 4.190476190476191
# 75% : 4.523809523809524
# IQR : 1.1904761904761902

# %%
# Low risk profile
low_risk = raw[raw['Level'] == 'Low']
low_average = np.mean(low_risk['Score'])
low_first_qrt = np.percentile(low_risk['Score'], 25)
low_second_qrt = np.percentile(low_risk['Score'], 50)
low_third_qrt = np.percentile(low_risk['Score'], 75)
low_iqr = low_thrid_qrt - low_first_qrt
low_risk_max = max(low_risk['Score'])
print(f'Low Risk Patients Stats : \nmax : {low_risk_max}\n25% : {low_first_qrt}\nmean : {low_second_qrt}\n75% : {low_thrid_qrt}\nIQR : {low_iqr}')
# Out:
# Low Risk Patients Stats :
# max : 4.571428571428571
# 25% : 2.2857142857142856
# mean : 2.5714285714285716
# 75% : 2.761904761904762
# IQR : 0.4761904761904763

# %%
data = {'Level' : ['High', 'Medium', 'Low'],
        'Mean': [high_average, medium_average, low_average],
        '1st Percentile' : [high_first_qrt, medium_first_qrt, low_first_qrt],
        '3rd Percentile' : [high_third_qrt, medium_third_qrt, low_third_qrt],
        'IQR' : [iqr, medium_iqr, low_iqr]
}

summary_df = pd.DataFrame(data)
summary_df
# Out:
#     Level      Mean  1st Percentile  3rd Percentile       IQR
# 0    High  5.600391        5.285714        5.904762  0.619048
# 1  Medium  3.959122        3.333333        4.523810  1.190476
# 2     Low  2.663209        2.285714        2.761905  0.476190

# %%
writer = pd.ExcelWriter('patients_stats_by_level.xlsx')
high_risk.describe().transpose().to_excel(writer, 'High')
medium_risk.describe().transpose().to_excel(writer, 'Medium')
low_risk.describe().transpose().to_excel(writer, 'Low')
writer.save()

# %%
high_risk.describe().transpose()
# Out:
#                           count       mean        std   min        25%  \
# Age                       365.0  37.320548  10.724253  18.0  29.000000
# Gender                    365.0   1.309589   0.462959   1.0   1.000000
# Air Pollution             365.0   5.693151   1.274898   2.0   6.000000
# Alcohol use               365.0   6.830137   1.157238   4.0   7.000000
# Dust Allergy              365.0   6.616438   0.917326   2.0   7.000000
# OccuPational Hazards      365.0   6.479452   0.982115   3.0   7.000000
# Genetic Risk              365.0   6.375342   0.821380   5.0   6.000000
# chronic Lung Disease      365.0   5.827397   1.002916   4.0   6.000000
# Balanced Diet             365.0   6.619178   0.633466   4.0   6.000000
# Obesity                   365.0   6.682192   1.004296   3.0   7.000000
# Smoking                   365.0   6.073973   2.159189   2.0   6.000000
# Passive Smoker            365.0   6.528767   1.775093   3.0   7.000000
# ...

# %%
medium_risk.describe().transpose()
# Out:
#                           count       mean        std        min        25%  \
# Age                       332.0  38.620482  13.015234  14.000000  32.000000
# Gender                    332.0   1.406627   0.491945   1.000000   1.000000
# Air Pollution             332.0   2.933735   1.874090   1.000000   1.000000
# Alcohol use               332.0   4.198795   2.650246   1.000000   2.000000
# Dust Allergy              332.0   5.442771   1.464497   3.000000   4.000000
# OccuPational Hazards      332.0   4.716867   2.036959   2.000000   3.000000
# Genetic Risk              332.0   4.292169   2.068801   2.000000   2.000000
# chronic Lung Disease      332.0   3.963855   1.605849   2.000000   2.000000
# Balanced Diet             332.0   3.512048   1.757979   2.000000   2.000000
# Obesity                   332.0   3.903614   1.378422   2.000000   3.000000
# Smoking                   332.0   2.454819   1.669273   1.000000   1.000000
# ...

# %%
low_risk.describe().transpose()
# Out:
#                           count       mean        std   min        25%  \
# Age                       303.0  35.412541  12.126736  17.0  25.000000
# Gender                    303.0   1.508251   0.500759   1.0   1.000000
# Air Pollution             303.0   2.600660   1.110873   1.0   2.000000
# Alcohol use               303.0   2.231023   1.260490   1.0   1.000000
# Dust Allergy              303.0   3.112211   1.659994   1.0   2.000000
# OccuPational Hazards      303.0   3.000000   1.524632   1.0   2.000000
# Genetic Risk              303.0   2.732673   1.432067   1.0   2.000000
# chronic Lung Disease      303.0   3.092409   1.696717   1.0   2.000000
# Balanced Diet             303.0   3.000000   1.567467   1.0   2.000000
# Obesity                   303.0   2.409241   1.053619   1.0   2.000000
# Smoking                   303.0   3.023102   1.778122   1.0   2.000000
# Passive Smoker            303.0   2.633663   1.352379   1.0   2.000000
# ...
